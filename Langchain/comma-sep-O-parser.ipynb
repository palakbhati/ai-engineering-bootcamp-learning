# %%
# %load_ext dotenv
# %dot_env

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import list_output_parser

# %%
chat = ChatOpenAI(model_name = 'gpt-4',
                  model_kwargs = {'seed': 365},
                  temperature = 0,
                  max_tokens = 100)

# %%
message_h = HumanMessage(content = "can you give me an interesting fact i porbably didnt know about")

# %%
response = chat.invoke([message_h])
print(response.content)

# %%
list_output_parser = CommaSeparatedOutputParser()

# %%
response_parsed = list_output_parser.invoke(response)

# %%
response_parsed

# %%
list_output_parser.get_format_instructions())
