# %%
# %load_ext dotenv
# %dot_env

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import HumanMesssage
from langchain_core.output_parsers import DatetimeOutputParser

# %%
chat = ChatOpenAI(model_name = 'gpt-4',
                  model_kwargs = {'seed': 365},
                  temperature = 0,
                  max_tokens = 100)

# %%
message_h = HumanMessage(content = f''' when i was born?

# %%
print(message_h.content)

# %%
response = chat.invoke([message_h])
print(response.content)

# %%
date_output_parser = DateOutputParser()

# %%
response_parsed = list_output_parser.invoke(response)

# %%
response_parsed

# %%
print(date_output_parser.get_format_instructions())
