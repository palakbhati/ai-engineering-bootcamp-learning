# %% [markdown]
# # ChatOpenAI

# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai.chat_models import ChatOpenAI

# %%
chat = ChatOpenAI(model_name = 'gpt-4' , model_kwargs = {'seed':365} , temperature = 0)

# %%
response = chat.invoke('''I've recently adopted a dog. Could you suggest some dogs names?''')

# %%
'''I've recently adopted a dog.
Could you suggest some dod names? '''

"""I've recently adopted a dog.
Could you suggest some dog names? """

# %%
print(response.content)
