# %% [markdown]
# # retrival augumented genration

# %% [markdown]
# # Indexing: document loading with PyPDF Loader

# %%
from langchain_community.document_loaders import PyPDFLoader
import copy

# %%
loader_pdf = pyPDFLoader('science.pdf')

# %%
pages_pdf = loader_pdf.load()

# %%
pages_pdf

# %%
pages_pdf_cut = copy.deepcopy(pages_pdf)

# %%
" ".join(pages_pdf_cut[0].page_content.split())

# %%
for i in pages_pdf_cut:
    i.page_content = " ".join(i.page_content.split())

# %%
pages_pdf_cut

# %%
pages_pdf[0].page_content , pages_pdf_cut
