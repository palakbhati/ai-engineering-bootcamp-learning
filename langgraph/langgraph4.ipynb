# %% [markdown]
# # The removeMessages Class

# %% [markdown]
# # set the openAI key as an environemnt variable

# %%
# %load_ext dotenv
# %dotenv
# %load_ext mypy_ipython

# %% [markdown]
# ## import relevant classes and functions

# %%
from langchain.graph import START , END , StateGraph
from typing_extensions import TypedDict
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage , BaseMessage
from langchain_core.runnable import Runnable
from collections.abc import Sequence
from typing import Literal , Annotated

# %% [markdown]
# # get famimilar with RemoveMessages

# %%
my_list = add_messages([AIMessage("Hey, Oscar. How can i assist you?")],
                        [HumanMessage("Could you summarize today's news?"),
                        AIMessage("would you like to ask one more questions"),
                        HumanMessages("yes"),
                        AIMessage("Hey, Oscar. How can i assist you?")],
                        [HumanMessage("Could you summarize today's news?"),
                        AIMessage("would you like to ask one more questions"),
                        HumanMessages("yes")])

# %%
my_list[:-5]

# %%
remove_messages = [RemoveMessage(id = =i.id) for i in my_list[:-5]]

# %%
add_messages(my_list , remove_messages)
